# %% [markdown]
# # Matplotlib total
# 다양한 형태의 그래프를 통해서 데이터 시각화를 할 수 있는 라이브러리

# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac
matplotlib.rcParams['font.size'] = 15 # 글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시, 마이너스 글자가 깨지는 현상을 해결

# %% [markdown]
# # 1. Basic graph

# %%
x = [1, 2, 3]
y = [2, 4, 8]
plt.plot(x, y)

# %%
print(plt.plot(x, y))
# Out:
# [<matplotlib.lines.Line2D object at 0x7f9a7150e850>]

# %%
plt.plot(x, y)
plt.show()

# %% [markdown]
# ## Naming Title

# %%
plt.plot(x, y)
plt.title('Line Graph')
# Out:
# Text(0.5, 1.0, 'Line Graph')

# %%
plt.plot(x, y)
plt.title('Graph name2', fontdict={'family':'HYGungSo-Bold', 'size':20}) # 개별 폰트 설정
# Out:
# Text(0.5, 1.0, 'Graph name2')

# %%
import matplotlib.font_manager as fm
fm.fontManager.ttflist # 사용 가능한 폰트 확인
[f.name for f in fm.fontManager.ttflist]
# Out:
# ['STIXSizeThreeSym',
#  'DejaVu Sans Mono',
#  'DejaVu Serif Display',
#  'DejaVu Serif',
#  'cmex10',
#  'STIXGeneral',
#  'STIXSizeTwoSym',
#  'cmsy10',
#  'cmtt10',
#  'DejaVu Sans',
#  'DejaVu Sans Display',
#  'STIXSizeFourSym',
#  'STIXNonUnicode',
#  'STIXGeneral',
#  'STIXGeneral',
#  'DejaVu Sans',
#  'STIXNonUnicode',
#  'STIXSizeThreeSym',
#  'DejaVu Serif',
#  'DejaVu Sans',
#  'STIXSizeFiveSym',
#  'DejaVu Sans Mono',
#  'DejaVu Sans',
#  'STIXSizeTwoSym',
#  'STIXSizeOneSym',
#  'DejaVu Serif',
#  'cmss10',
#  'STIXGeneral',
#  'STIXSizeFourSym',
#  'STIXNonUnicode',
#  'cmb10',
#  'DejaVu Serif',
#  'cmmi10',
#  'STIXSizeOneSym',
#  'DejaVu Sans Mono',
#  'STIXNonUnicode',
#  'DejaVu Sans Mono',
#  'cmr10',
#  'Noto Sans Avestan',
#  'Trebuchet MS',
#  'Noto Sans Khojki',
#  'Ayuthaya',
#  'Noto Sans NKo',
#  'Avenir',
#  'Gujarati Sangam MN',
#  'Arial Narrow',
#  'Hiragino Sans',
#  'Hoefler Text',
#  'Noto Sans Old Italic',
#  'Noto Sans Rejang',
#  'Noto Sans Tai Viet',
#  'Hiragino Mincho ProN',
#  'STIXNonUnicode',
#  'Kohinoor Gujarati',
#  'PT Serif Caption',
#  'Farah',
#  'Impact',
#  'Helvetica Neue',
#  'Mukta Mahee',
#  'Sana',
#  'Geeza Pro',
#  'STIXSizeTwoSym',
#  'STIXIntegralsSm',
#  'Hiragino Sans',
#  'Noto Sans Cypriot',
#  'Noto Sans Tagbanwa',
#  'Arial Narrow',
#  'Noto Sans Duployan',
#  'Georgia',
#  'Noto Sans Lisu',
#  'Arial Black',
#  'Noto Nastaliq Urdu',
#  'Copperplate',
#  'Charter',
#  'Zapf Dingbats',
#  'Lao MN',
#  'Times New Roman',
#  'STIXSizeTwoSym',
#  'Heiti TC',
#  'STIXIntegralsUp',
#  'Noto Sans Osage',
#  'Chalkboard SE',
#  'Arial Hebrew',
#  'Devanagari MT',
#  'Noto Sans Adlam',
#  'Hiragino Sans',
#  'PT Sans',
#  'Noto Sans Palmyrene',
#  'DIN Alternate',
#  'STIXIntegralsUpD',
#  'STIXSizeFourSym',
#  'Sinhala Sangam MN',
#  'Baghdad',
#  'STIXVariants',
#  'Noto Sans Mongolian',
#  'American Typewriter',
#  'PT Serif',
#  'Athelas',
#  'Diwan Thuluth',
#  'Al Tarikh',
#  'Trattatello',
#  'Papyrus',
#  'PT Mono',
#  'Cochin',
#  'Times',
#  'Kohinoor Telugu',
#  'Galvji',
#  'Noto Sans Hatran',
#  'New Peninim MT',
#  'Big Caslon',
#  'Noto Sans Miao',
#  'Arial',
#  'Noto Sans Chakma',
#  'Chalkboard',
#  'Hiragino Sans',
#  'Telugu MN',
#  '.SF NS Mono',
#  'STIXIntegralsUp',
#  'Noto Sans Javanese',
#  'Noto Sans Egyptian Hieroglyphs',
#  'Thonburi',
#  'Diwan Kufi',
#  'Myanmar MN',
#  'Iowan Old Style',
#  'Noto Sans Lepcha',
#  'Noto Sans Meetei Mayek',
#  'Baskerville',
#  'Noto Sans Old Persian',
#  'Bodoni 72 Smallcaps',
#  'Noto Serif Balinese',
#  'Chalkduster',
#  'STIXSizeOneSym',
#  'Noto Sans Inscriptional Parthian',
#  'STIXIntegralsUpSm',
#  'Hiragino Sans',
#  'Tamil MN',
#  'Arial Narrow',
#  'STIXNonUnicode',
#  'Noto Sans Armenian',
#  'Noto Sans Gunjala Gondi',
#  'Mishafi Gold',
#  'Avenir Next',
#  'ITF Devanagari',
#  'Waseem',
#  'Noto Sans Cham',
#  'Noto Sans Buhid',
#  'Noto Sans Linear B',
#  '.Aqua Kana',
#  'Noto Sans Carian',
#  'STIXVariants',
#  'Noto Sans Coptic',
#  'Noto Sans Modi',
#  'Bangla MN',
#  'Courier New',
#  'Optima',
#  'Palatino',
#  'Noto Sans Bassa Vah',
#  'Courier',
#  'Lucida Grande',
#  'Noto Sans Pahawh Hmong',
#  'Bodoni 72',
#  'Hiragino Sans',
#  '.New York',
#  'Noto Sans Pau Cin Hau',
#  'Noto Sans Osmanya',
#  'Silom',
#  'Arial Rounded MT Bold',
#  'Apple Braille',
#  'Noto Sans Lydian',
#  'Apple SD Gothic Neo',
#  'Zapfino',
#  'Noto Sans Tirhuta',
#  'Kannada MN',
#  'Shree Devanagari 714',
#  'STIXGeneral',
#  'STIXSizeFiveSym',
#  'Kohinoor Devanagari',
#  '.SF NS Rounded',
#  'Verdana',
#  'Verdana',
#  'Mshtakan',
#  'Webdings',
#  'Tahoma',
#  'Noto Sans Old North Arabian',
#  'Trebuchet MS',
#  'Noto Sans Takri',
#  'Farisi',
#  'Noto Sans Tai Le',
#  'Myanmar Sangam MN',
#  'Noto Sans Glagolitic',
#  'Trebuchet MS',
#  'Noto Serif Ahom',
#  'Wingdings 2',
#  'Hiragino Sans',
#  'Noto Sans Syloti Nagri',
#  'Arial',
#  'AppleMyungjo',
#  'Kannada Sangam MN',
#  '.SF Compact Rounded',
#  'Geneva',
#  'Noto Sans Khudawadi',
#  'Verdana',
#  'Noto Sans Sora Sompeng',
#  'Damascus',
#  'Noto Sans Linear A',
#  'Noteworthy',
#  'Arial Narrow',
#  'Noto Sans Newa',
#  'Noto Sans Elbasan',
#  'System Font',
#  'Party LET',
#  '.SF Compact',
#  'Noto Sans Multani',
#  'Noto Serif Yezidi',
#  'STIXGeneral',
#  'Noto Sans Wancho',
#  'Verdana',
#  'STIXNonUnicode',
#  'Bradley Hand',
#  'Devanagari Sangam MN',
#  'Brush Script MT',
#  'Noto Sans Buginese',
#  'Apple Braille',
#  'STIXSizeThreeSym',
#  'Noto Sans Old Hungarian',
#  'Comic Sans MS',
#  'Al Nile',
#  'Wingdings 3',
#  'Raanana',
#  'Muna',
#  'Telugu Sangam MN',
#  'STIXIntegralsD',
#  'Gill Sans',
#  'Noto Sans Saurashtra',
#  'Noto Sans Cuneiform',
#  'Luminari',
#  'InaiMathi',
#  'KufiStandardGK',
#  'Seravek',
#  'STIXGeneral',
#  'Apple Chancery',
#  'Noto Sans Brahmi',
#  'Times New Roman',
#  'STIXNonUnicode',
#  'Heiti TC',
#  'Noto Sans PhagsPa',
#  'Noto Sans Old Permic',
#  'Hoefler Text',
#  'Noto Sans Kannada',
#  'Noto Sans Mandaic',
#  'Noto Sans Manichaean',
#  'Noto Sans Syriac',
#  'Noto Sans Bhaiksuki',
#  'Noto Sans Imperial Aramaic',
#  'Apple Braille',
#  'Noto Sans Lycian',
#  'Malayalam Sangam MN',
#  'Noto Sans Tagalog',
#  'Courier New',
#  'STIXIntegralsD',
#  'Sinhala MN',
#  'Noto Sans Kharoshthi',
#  'Courier New',
#  'Hiragino Maru Gothic Pro',
#  'Apple Braille',
#  'Hiragino Sans',
#  'Beirut',
#  'Noto Sans Meroitic',
#  'Tahoma',
#  'Menlo',
#  'Marker Felt',
#  'Microsoft Sans Serif',
#  'Noto Sans Tai Tham',
#  'Herculanum',
#  'Noto Sans Vai',
#  'STIXIntegralsSm',
#  'Noto Sans Warang Citi',
#  'STIXSizeThreeSym',
#  '.SF Compact',
#  'Noto Sans Kaithi',
#  'System Font',
#  'Noto Sans Caucasian Albanian',
#  'Kohinoor Bangla',
#  'Noto Sans Thaana',
#  'Arial Unicode MS',
#  'Phosphate',
#  'SignPainter',
#  'Khmer Sangam MN',
#  'Monaco',
#  'Arial',
#  'STIXSizeFourSym',
#  'Kailasa',
#  'Academy Engraved LET',
#  'Andale Mono',
#  'Arial Unicode MS',
#  'Lao Sangam MN',
#  'Futura',
#  'Gurmukhi MT',
#  'Apple Symbols',
#  'Noto Sans Ugaritic',
#  'Khmer MN',
#  'Noto Sans Nabataean',
#  'Georgia',
#  'Corsiva Hebrew',
#  'Times New Roman',
#  'Songti SC',
#  'Plantagenet Cherokee',
#  'Noto Sans Ol Chiki',
#  'Noto Sans Mahajani',
#  'Noto Sans Sundanese',
#  'DIN Condensed',
#  'Krungthep',
#  'Gurmukhi Sangam MN',
#  'Sukhumvit Set',
#  'STIXSizeOneSym',
#  'Noto Sans New Tai Lue',
#  'Superclarendon',
#  'Apple Braille',
#  'Noto Sans Gothic',
#  'AppleGothic',
#  'Noto Sans Bamum',
#  'Euphemia UCAS',
#  'Noto Sans Old Turkic',
#  '.SF NS Mono',
#  'Noto Sans Limbu',
#  'Marion',
#  'Bodoni Ornaments',
#  'Noto Sans Hanifi Rohingya',
#  'Noto Sans Myanmar',
#  'Helvetica',
#  'Hiragino Sans GB',
#  'Noto Sans Mende Kikakui',
#  'PingFang HK',
#  'Noto Sans Inscriptional Pahlavi',
#  'Noto Sans Hanunoo',
#  'Noto Sans Masaram Gondi',
#  'Avenir Next Condensed',
#  'Noto Sans Old South Arabian',
#  'Noto Sans Batak',
#  'Snell Roundhand',
#  'Nadeem',
#  'Symbol',
#  'STIXIntegralsUpSm',
#  'Gurmukhi MN',
#  'Oriya MN',
#  'Arial',
#  'Trebuchet MS',
#  'Skia',
#  'STIXIntegralsUpD',
#  'Oriya Sangam MN',
#  '.SF Arabic',
#  'Noto Sans Sharada',
#  'Georgia',
#  'Georgia',
#  'Mishafi',
#  'Noto Sans Phoenician',
#  'Noto Sans Tifinagh',
#  'Hiragino Sans',
#  'Noto Sans Yi',
#  '.New York',
#  'Tamil Sangam MN',
#  'Noto Sans Mro',
#  'Malayalam MN',
#  'Wingdings',
#  'Rockwell',
#  'Bodoni 72 Oldstyle',
#  'Noto Sans Kayah Li',
#  'Noto Sans Samaritan',
#  'Hiragino Sans',
#  'STIXGeneral',
#  'Sathu',
#  'Savoye LET',
#  'Comic Sans MS',
#  'Noto Serif Myanmar',
#  'Kokonor',
#  'Gujarati MT',
#  'Times New Roman',
#  'Noto Sans Marchen',
#  'Bangla Sangam MN',
#  '.Keyboard',
#  'Noto Sans Oriya',
#  'Courier New',
#  'DecoType Naskh',
#  'Noto Sans Siddham',
#  'Noto Sans Psalter Pahlavi',
#  'Kefa',
#  'Didot',
#  'Al Bayan']

# %%
plt.plot(x, y)
plt.title('꺾은선 그래프')
# Out:
# Text(0.5, 1.0, '꺾은선 그래프')

# %%
plt.plot([-1, 0, 1], [-5, -1, 2], label='data ?? ')
plt.xlabel('X', color='red')
plt.ylabel('Y', color='#00aa00')
plt.legend(loc='lower right')

# %%
#keep order
plt.figure(facecolor='yellow', figsize=(10, 5))
plt.plot([-1, 0, 1], [-5, -1, 2], color= 'pink', linewidth=3, marker='o', markersize=7, markeredgecolor='red', 
         markerfacecolor='yellow',label='data ?? ')

# marker='o' marker='v'  marker='X'

plt.xlabel('X', color='red')
plt.ylabel('Y', color='#00aa00')
plt.legend(loc=(.8, .5))

plt.figure(facecolor='grey', figsize=(8, 5))
plt.plot([-1, 0, 1], [-5, -1, 2], label='data ?? ')
plt.xlabel('X', color='red')
plt.ylabel('Y', color='#00aa00')
plt.legend(loc=(.8, .5))

# %%
plt.plot(x, y, marker='o', mfc='red', ms=10, alpha=0.2) # alpha : 투명도 (0~1)

# %%
print(x)
print(y)
plt.plot(x, y, linestyle=':')
plt.plot(x, y, linestyle='--')
plt.plot(x, y, linestyle='-.')
plt.plot(x, y, 'gv-.', linewidth=3, markersize=15, markeredgecolor='red', 
         markerfacecolor='yellow',label='data ?? ') # color g. green, marker, linestyle
plt.savefig('jinsgraph.png', dpi=300) #dpi adjust saved graph size

for idx, txt in enumerate(y):
    plt.text(x[idx], y[idx] + 0.2, txt, ha='center', color='black')
# Out:
# [1, 2, 3]
# [2, 4, 8]

# %%
plt.plot(x, y, 'go')

# %%
days = [1, 2, 3] # 1일, 2일, 3일
az = [2, 4, 8] # (단위 : 만명) 1일부터 3일까지 아스트라제네카 접종인구
pfizer = [5, 1, 3] # 화이타
moderna = [1, 2, 5] # 모더나

plt.plot(days, az, label='az')
plt.plot(days, pfizer, 'go--', label='pfizer')
plt.plot(days, moderna, 'rs-.', label='moderna')

plt.legend()

# %%
days = [1, 2, 3] # 1일, 2일, 3일
az = [2, 4, 8] # (단위 : 만명) 1일부터 3일까지 아스트라제네카 접종인구
pfizer = [5, 1, 3] # 화이타
moderna = [1, 2, 5] # 모더나

plt.plot(days, az, label='az')
plt.plot(days, pfizer, 'go--', label='pfizer')
plt.plot(days, moderna, 'rs-.', label='moderna')

plt.legend(ncol=3)

# %%
labels = ['abc', 'def', 'ghi'] # 이름
values = [190, 187, 184] # 키

colors = ['r', 'g', 'b']

plt.bar(labels, values, color=colors, alpha=0.5, width=0.5)
plt.ylim(175, 195)
# Out:
# (175.0, 195.0)

# %%
labels = ['강백호', '서태웅', '정대만'] # 이름
values = [190, 187, 184] # 키
ticks = ['1', '2', '3']

plt.bar(labels, values)

plt.xticks(labels, ticks, rotation=30)
plt.yticks(rotation=45)
# Out:
# (array([  0.,  50., 100., 150., 200.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
labels = ['abc', 'def', 'ghi'] # 이름
values = [190, 187, 184] # 키

plt.barh(labels, values)
plt.xlim(175, 195)
# Out:
# (175.0, 195.0)

# %%
bar = plt.bar(labels, values)
plt.ylim(175, 195)

for idx, rect in enumerate(bar):
    plt.text(idx, rect.get_height() + 0.5, values[idx], ha='center', color='blue')

# %%
import pandas as pd
df = pd.read_excel('../Matplotlib/score.xlsx')
df
# Out:
#   지원번호   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0   1번  채치수  북산고  197   90   85  100  95  85      Python
# 1   2번  정대만  북산고  184   40   35   50  55  25        Java
# 2   3번  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3   4번  서태웅  북산고  187   40   60   70  75  80         NaN
# 4   5번  강백호  북산고  188   15   20   10  35  10         NaN
# 5   6번  변덕규  능남고  202   80  100   95  85  80           C
# 6   7번  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7   8번  윤대협  능남고  190  100   85   90  95  95          C#

# %%
plt.figure(facecolor='yellow', figsize=(10, 5))
plt.plot(df['지원번호'], df['영어'], 'bv-', linewidth=1, markersize=7, markeredgecolor='black', 
         markerfacecolor='yellow', label='pfizer')
plt.plot(df['지원번호'], df['수학'], 'gv-.', linewidth=1, markersize=7, markeredgecolor='red', label='second')

plt.grid(axis='y', color='purple', alpha=0.5, linestyle='--', linewidth=2)
plt.legend(ncol=2, loc='lower right') #must include for label

# %%
font_path = r'C:\Users\user\NanumBarunGothic.ttf'
fontprop = fm.FontProperties(fname=font_path, size=12)


plt.plot(df['지원번호'], df['영어'])
plt.plot(df['지원번호'], df['수학'])



plt.grid(axis='y', color='purple', alpha=0.5, linestyle='--', linewidth=2)

# %%
plt.bar(df['이름'], df['국어'], label='국어')
plt.bar(df['이름'], df['영어'], bottom=df['국어'], label='영어')
plt.bar(df['이름'], df['수학'], bottom=df['국어'] + df['영어'], label='수학')

plt.xticks(rotation=60)
plt.legend()

# %%
import numpy as np
N=df.shape[0]
index = np.arange(N)
index
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7])

# %%
plt.figure(figsize=(10, 5))
plt.title('학생별 성적')

print(index - w)
print(index)
print(df['영어'])
print(df['이름'])


w = 0.25
plt.bar(index - w, df['국어'], width=w, label='국어')
plt.bar(index, df['영어'], width=w, label='영어')
plt.bar(index + w, df['수학'], width=w, label='수학')
plt.legend(ncol=3)
plt.xticks(index, df['이름'], rotation=60)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [64], in <cell line: 4>()
#       1 plt.figure(figsize=(10, 5))
#       2 plt.title('학생별 성적')
# ----> 4 print(index - w)
#       5 print(index)
#       6 print(df['영어'])
#
# NameError: name 'w' is not defined

# %%
w = 0.25
plt.bar(index - w, df['국어'], width=w)
plt.bar(index, df['영어'], width=w)
plt.bar(index + w, df['수학'], width=w)
# Out:
# <BarContainer object of 8 artists>

# %%
plt.figure(figsize=(10, 5))
plt.title('학생별 성적')

w = 0.25
plt.bar(index - w, df['국어'], width=w, label='국어')
plt.bar(index, df['영어'], width=w, label='영어')
plt.bar(index + w, df['수학'], width=w, label='수학')
plt.legend(ncol=3)
plt.xticks(index, df['이름'], rotation=60)
plt.show()

# %%
values = [30, 25, 20, 13, 10, 2]
labels = ['Python', 'Java', 'Javascript', 'C#', 'C/C++', 'ETC']
# explode = [0.2, 0.1, 0, 0, 0, 0]
explode = [0.05] * 6


plt.pie(values, labels=labels, explode=explode)
plt.title('언어별 선호도')
plt.legend(loc=(1.2, 0.3), title='언어별 선호도')
plt.show()

# %%
plt.figure(figsize=(15, 8))
values = [30, 25, 20, 13, 10, 2]
labels = ['Python', 'Java', 'Javascript', 'C#', 'C/C++', 'ETC']

plt.pie(values, labels=labels, autopct='%.1f%%', startangle=90, counterclock=False, explode=explode, textprops={'fontsize': 15})

plt.title('언어별 선호도')
plt.legend(loc=(1.2, 0.3), title='언어별 선호도')

plt.show()

# %%
plt.figure(figsize=(13, 6))
colors = ['#ffadad', '#ffd6a5', '#fdffb6', '#caffbf', '#9bf6ff', '#a0c4ff']

def custom_autopct(pct):
    # return ('%.1f%%' % pct) if pct >= 10 else ''
    # return '{:.1f}%'.format(pct) if pct >= 10 else ''
    return '{:.0f}%'.format(pct) if pct >= 10 else ''

wedgeprops={'width':0.6, 'edgecolor':'w', 'linewidth':2}
plt.pie(values, labels=labels, autopct=custom_autopct, startangle=90, counterclock=False, colors=colors, wedgeprops=wedgeprops, pctdistance=0.7)
plt.show()

# %%
grp = df.groupby('학교')
grp

# %%
values = [grp.size()['북산고'], grp.size()['능남고']] # [5, 3]
labels = ['북산고', '능남고']

explode = [0.05] * 6


plt.pie(values, labels=labels, startangle=90, counterclock=False)
plt.title('소속 학교')
plt.show()

# %%
df['학년'] = [3, 5, 2, 3, 1, 5, 2, 5]
df
# Out:
#   지원번호   이름   학교    키   국어   영어   수학  과학  사회        SW특기  학년
# 0   1번  채치수  북산고  197   90   85  100  95  85      Python   3
# 1   2번  정대만  북산고  184   40   35   50  55  25        Java   5
# 2   3번  송태섭  북산고  168   80   75   70  80  75  Javascript   2
# 3   4번  서태웅  북산고  187   40   60   70  75  80         NaN   3
# 4   5번  강백호  북산고  188   15   20   10  35  10         NaN   1
# 5   6번  변덕규  능남고  202   80  100   95  85  80           C   5
# 6   7번  황태산  능남고  188   55   65   45  40  35      PYTHON   2
# 7   8번  윤대협  능남고  190  100   85   90  95  95          C#   5

# %%
import numpy as np

plt.figure(figsize=(7, 7))
sizes = df['학년'] * 500 # 1학년 = 500, 2학년 = 1000, 3학년 = 1500

plt.scatter(df['영어'], df['수학'], s=sizes, c=df['학년'], cmap='viridis_r', alpha=0.6)
#cmap is colormap viridis_r,  virdis, jet
#alpha is opacity
#c is color

plt.xlabel('영어 점수')
plt.ylabel('수학 점수')
plt.colorbar(ticks=[1, 2, 3, 4, 5], label='학년', shrink=0.5, orientation='horizontal')

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 10)) # 2 x 2 에 해당하는 plot 들을 생성
fig.suptitle('여러 그래프 넣기')

# 첫 번째 그래프
axs[0, 0].bar(df['이름'], df['국어'], label='국어점수') # 데이터 설정
axs[0, 0].set_title('첫 번째 그래프') # 제목
axs[0, 0].legend() # 범례

axs[0, 0].set(xlabel='이름', ylabel='점수') # x, y 축 label
axs[0, 0].set_facecolor('lightyellow') # 전면 색
axs[0, 0].grid(linestyle='--', linewidth=0.5)

# 두 번째 그래프
axs[0, 1].plot(df['이름'], df['수학'], label='수학')
axs[0, 1].plot(df['이름'], df['영어'], label='영어')
axs[0, 1].legend()

# 세 번째 그래프
axs[1, 0].barh(df['이름'], df['키'])

# 네 번째 그래프
axs[1, 1].plot(df['이름'], df['사회'], color='green', alpha=0.5)
